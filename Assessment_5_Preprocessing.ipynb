# %%
import pandas as pd

# %%
df=pd.read_csv('/content/diabetes.txt')

# %%
df.head()
# Out:
#    Unnamed: 0   ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  \
# 0           0  502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4
# 1           1  735      34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1
# 2           2  420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4
# 3           3  680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4
# 4           4  504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8
#
#    LDL  VLDL   BMI CLASS
# 0  1.4   0.5  24.0     N
# 1  2.1   0.6  23.0     N
# 2  1.4   0.5  24.0     N
# 3  1.4   0.5  24.0     N
# 4  2.0   0.4  21.0     N

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1009 non-null   int64
#  1   ID          1009 non-null   int64
#  2   No_Pation   1009 non-null   int64
#  3   Gender      1006 non-null   object
#  4   AGE         1008 non-null   float64
#  5   Urea        1008 non-null   float64
#  6   Cr          1007 non-null   float64
#  7   HbA1c       1006 non-null   float64
#  8   Chol        1007 non-null   float64
#  9   TG          1007 non-null   float64
#  10  HDL         1008 non-null   float64
#  11  LDL         1007 non-null   float64
#  12  VLDL        1008 non-null   float64
#  13  BMI         1009 non-null   float64
#  14  CLASS       1009 non-null   object
# dtypes: float64(10), int64(3), object(2)
# memory usage: 118.4+ KB

# %%
df.describe()
# Out:
#         Unnamed: 0           ID     No_Pation          AGE         Urea  \
# count  1009.000000  1009.000000  1.009000e+03  1008.000000  1008.000000
# mean    504.000000   338.166501  2.717468e+05    53.596230     5.132979
# std     291.417513   239.479644  3.365681e+06     8.743882     2.930873
# min       0.000000     1.000000  1.230000e+02    25.000000     0.500000
# 25%     252.000000   126.000000  2.406400e+04    51.000000     3.700000
# 50%     504.000000   294.000000  3.439900e+04    55.000000     4.600000
# 75%     756.000000   547.000000  4.539100e+04    59.000000     5.700000
# max    1008.000000   800.000000  7.543566e+07    79.000000    38.900000
#
#                 Cr        HbA1c         Chol           TG          HDL  \
# count  1007.000000  1006.000000  1007.000000  1007.000000  1008.000000
# mean     68.938431     8.281372     4.862483     2.346783     1.202728
# std      59.815673     2.534861     1.298665     1.396438     0.658038
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0   ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  \
# 1004        1004  194     454316      F  57.0   4.1  70.0    9.3   5.3  3.3
# 1005        1005  195       4543      f  55.0   4.1  34.0   13.9   5.4  1.6
# 1006        1006  249      48822      M  55.0   4.2  57.0    8.9   5.3  3.1
# 1007        1007   88      21747      M  41.0   3.8  48.0    4.3   3.2  4.5
# 1008        1008   62      46059      M  55.0   7.0  56.0    9.1   3.7  1.9
#
#       HDL  LDL  VLDL   BMI CLASS
# 1004  1.0  1.4   1.3  29.0    Y
# 1005  1.6  3.1   0.7  33.0    Y
# 1006  0.7  3.3   1.4  27.0     Y
# 1007  1.3  1.8   1.1  21.0     N
# 1008  0.7  2.3   0.9  27.0     Y

# %%
df.drop(columns=['Unnamed: 0'],axis=1,inplace=True)

# %%
df.head()
# Out:
#     ID  No_Pation Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0   0.4
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N

# %%
df.dtypes
# Out:
# ID             int64
# No_Pation      int64
# Gender        object
# AGE          float64
# Urea         float64
# Cr           float64
# HbA1c        float64
# Chol         float64
# TG           float64
# HDL          float64
# LDL          float64
# VLDL         float64
# BMI          float64
# CLASS         object
# dtype: object

# %%
df.rename(columns={'ID':'Visit_Id'},inplace=True)

# %%
df.rename(columns={'No_Pation':'Patient_ID'},inplace=True)

# %%
df.head()
# Out:
#    Visit_Id  Patient_ID Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  \
# 0       502       17975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 1       735       34221      M  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1
# 2       420       47975      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 3       680       87656      F  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 4       504       34223      M  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0
#
#    VLDL   BMI CLASS
# 0   0.5  24.0     N
# 1   0.6  23.0     N
# 2   0.5  24.0     N
# 3   0.5  24.0     N
# 4   0.4  21.0     N

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M', nan, 'f'], dtype=object)

# %%
df['CLASS'].unique()
# Out:
# array(['N', 'N ', 'P', 'Y', 'Y '], dtype=object)

# %%
df['Gender'].replace({'F':'Female','M':'Male'},inplace=True)
df['CLASS'].replace({'N':'No diabetes','P':'Pre-diabetes','Y':'Yes,Diabetes'},inplace=True)
# Out:
# /tmp/ipykernel_1984/3997808427.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['CLASS'].replace({'N':'No diabetes','P':'Pre-diabetes','Y':'Yes,Diabetes'},inplace=True)

# %%
df.head()
# Out:
#    Visit_Id  Patient_ID  Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  \
# 0       502       17975  Female  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 1       735       34221    Male  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1
# 2       420       47975  Female  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 3       680       87656  Female  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 4       504       34223    Male  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0
#
#    VLDL   BMI        CLASS
# 0   0.5  24.0  No diabetes
# 1   0.6  23.0  No diabetes
# 2   0.5  24.0  No diabetes
# 3   0.5  24.0  No diabetes
# 4   0.4  21.0  No diabetes

# %%
df.head()
# Out:
#    Visit_Id  Patient_ID  Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  \
# 0       502       17975  Female  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 1       735       34221    Male  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1
# 2       420       47975  Female  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 3       680       87656  Female  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 4       504       34223    Male  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0
#
#    VLDL   BMI        CLASS
# 0   0.5  24.0  No diabetes
# 1   0.6  23.0  No diabetes
# 2   0.5  24.0  No diabetes
# 3   0.5  24.0  No diabetes
# 4   0.4  21.0  No diabetes

# %%
range=df.select_dtypes(include=['int64','float64']).describe()
# Out:
#           Visit_Id    Patient_ID          AGE         Urea           Cr  \
# count  1009.000000  1.009000e+03  1008.000000  1008.000000  1007.000000
# mean    338.166501  2.717468e+05    53.596230     5.132979    68.938431
# std     239.479644  3.365681e+06     8.743882     2.930873    59.815673
# min       1.000000  1.230000e+02    25.000000     0.500000     6.000000
# 25%     126.000000  2.406400e+04    51.000000     3.700000    48.000000
# 50%     294.000000  3.439900e+04    55.000000     4.600000    60.000000
# 75%     547.000000  4.539100e+04    59.000000     5.700000    73.000000
# max     800.000000  7.543566e+07    79.000000    38.900000   800.000000
#
#              HbA1c         Chol           TG          HDL          LDL  \
# count  1006.000000  1007.000000  1007.000000  1008.000000  1007.000000
# mean      8.281372     4.862483     2.346783     1.202728     2.611708
# std       2.534861     1.298665     1.396438     0.658038     1.115990
# ...

# %%
import matplotlib.pyplot as plt
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
scaled_df = (df[num_cols] - df[num_cols].min()) / (
    df[num_cols].max() - df[num_cols].min()
)
plt.figure(figsize=(12, 6))
plt.boxplot(
    scaled_df,
    labels=num_cols
)
plt.title("Box Plot of Numerical Columns")
plt.xlabel("Numerical Columns")
plt.ylabel("Scaled Values")
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipykernel_1984/2658308623.py:7: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %%
df.isna().sum()
# Out:
# Visit_Id      0
# Patient_ID    0
# Gender        3
# AGE           1
# Urea          1
# Cr            2
# HbA1c         3
# Chol          2
# TG            2
# HDL           1
# LDL           2
# VLDL          1
# BMI           0
# CLASS         0
# dtype: int64

# %%
df['Gender'].fillna(df['Gender'].mode()[0],inplace=True)

# %%
df.isna().sum()
# Out:
# Visit_Id      0
# Patient_ID    0
# Gender        0
# AGE           1
# Urea          1
# Cr            2
# HbA1c         3
# Chol          2
# TG            2
# HDL           1
# LDL           2
# VLDL          1
# BMI           0
# CLASS         0
# dtype: int64

# %%
df.dtypes
# Out:
# Visit_Id        int64
# Patient_ID      int64
# Gender         object
# AGE           float64
# Urea          float64
# Cr            float64
# HbA1c         float64
# Chol          float64
# TG            float64
# HDL           float64
# LDL           float64
# VLDL          float64
# BMI           float64
# CLASS          object
# dtype: object

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
df['AGE'].fillna(df['AGE'].mean(),inplace=True)
df['HbA1c'].fillna(df['HbA1c'].mean(),inplace=True)
df['Chol'].fillna(df['Chol'].mean(),inplace=True)
df['TG'].fillna(df['TG'].mean(),inplace=True)
df['HDL'].fillna(df['HDL'].mean(),inplace=True)
df['LDL'].fillna(df['LDL'].mean(),inplace=True)
df['VLDL'].fillna(df['VLDL'].mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# Visit_Id      0
# Patient_ID    0
# Gender        0
# AGE           0
# Urea          1
# Cr            2
# HbA1c         0
# Chol          0
# TG            0
# HDL           0
# LDL           0
# VLDL          0
# BMI           0
# CLASS         0
# dtype: int64

# %%
df['Urea'].fillna(df['Urea'].mean(),inplace=True)
df['Cr'].fillna(df['Cr'].mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# Visit_Id      0
# Patient_ID    0
# Gender        0
# AGE           0
# Urea          0
# Cr            0
# HbA1c         0
# Chol          0
# TG            0
# HDL           0
# LDL           0
# VLDL          0
# BMI           0
# CLASS         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(3)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[['AGE','HbA1c','BMI']].describe()
# Out:
#                AGE        HbA1c        BMI
# count  1006.000000  1006.000000  1006.0000
# mean     53.605960     8.283901    29.5867
# std       8.743325     2.531540     4.9520
# min      25.000000     0.900000    19.0000
# 25%      51.000000     6.500000    26.0000
# 50%      55.000000     8.000000    30.0000
# 75%      59.000000    10.175000    33.0000
# max      79.000000    16.000000    47.7500

# %%
cr_threshold=df['Cr'].quantile(0.995)
print(cr_threshold)
# Out:
# 401.0

# %%
df=df[df['Cr']<=cr_threshold]

# %%
urea_threshold=df['Urea'].quantile(0.999)
print(urea_threshold)
# Out:
# 26.397600000000327

# %%
df=df[df['Urea']<=urea_threshold]

# %%
lipts=['LDL','VLDL','HDL','TG','Chol']

# %%
q1=df[lipts].quantile(0.25)
q1
# Out:
# LDL     1.8
# VLDL    0.7
# HDL     0.9
# TG      1.5
# Chol    4.0
# Name: 0.25, dtype: float64

# %%
q3=df[lipts].quantile(0.75)
q3
# Out:
# LDL     3.3
# VLDL    1.5
# HDL     1.3
# TG      2.9
# Chol    5.6
# Name: 0.75, dtype: float64

# %%
IQR=q1-q3
print(IQR)
# Out:
# LDL    -1.5
# VLDL   -0.8
# HDL    -0.4
# TG     -1.4
# Chol   -1.6
# dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Gender']=le.fit_transform(df['Gender'])

# %%
df['Gender'].unique()
# Out:
# array([0, 1, 2])

# %%
df.head()
# Out:
#    Visit_Id  Patient_ID  Gender   AGE  Urea    Cr  HbA1c  Chol   TG  HDL  LDL  \
# 0       502       17975       0  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 1       735       34221       1  26.0   4.5  62.0    4.9   3.7  1.4  1.1  2.1
# 2       420       47975       0  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 3       680       87656       0  50.0   4.7  46.0    4.9   4.2  0.9  2.4  1.4
# 4       504       34223       1  33.0   7.1  46.0    4.9   4.9  1.0  0.8  2.0
#
#    VLDL   BMI        CLASS
# 0   0.5  24.0  No diabetes
# 1   0.6  23.0  No diabetes
# 2   0.5  24.0  No diabetes
# 3   0.5  24.0  No diabetes
# 4   0.4  21.0  No diabetes

# %%
scale_cols = ['Patient_ID', 'AGE', 'BMI', 'Cr','HbA1c','Chol','TG','HDL','LDL','VLDL','BMI']

# %%
df[scale_cols].describe()
# Out:
#          Patient_ID          AGE          BMI           Cr        HbA1c  \
# count  1.000000e+03  1000.000000  1000.000000  1000.000000  1000.000000
# mean   2.739192e+05    53.589596    29.570220    65.911877     8.283504
# std    3.380729e+06     8.764162     4.958491    37.784616     2.537955
# min    1.230000e+02    25.000000    19.000000     6.000000     0.900000
# 25%    2.406575e+04    51.000000    26.000000    48.000000     6.500000
# 50%    3.440050e+04    55.000000    30.000000    60.000000     8.000000
# 75%    4.539025e+04    59.000000    33.000000    73.000000    10.200000
# max    7.543566e+07    79.000000    47.750000   401.000000    16.000000
#
#               Chol           TG          HDL          LDL         VLDL  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      4.863945     2.345004     1.203853     2.610413     1.857650
# std       1.296029     1.398477     0.660154     1.115024     3.663586
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
df[scale_cols]=scaler.fit_transform(df[scale_cols])

# %%
df[scale_cols].describe()
# Out:
#          Patient_ID           AGE           BMI            Cr         HbA1c  \
# count  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03
# mean  -7.105427e-18  5.115908e-16 -5.258016e-16 -3.232969e-16 -5.684342e-17
# std    1.000500e+00  1.000500e+00  1.000500e+00  1.000500e+00  1.000500e+00
# min   -8.102785e-02 -3.263735e+00 -2.132808e+00 -1.586409e+00 -2.910689e+00
# 25%   -7.394218e-02 -2.956235e-01 -7.203817e-01 -4.742893e-01 -7.030844e-01
# 50%   -7.088369e-02  1.610091e-01  8.671893e-02 -1.565408e-01 -1.117616e-01
# 75%   -6.763136e-02  6.176416e-01  6.920444e-01  1.876867e-01  7.555118e-01
# max    2.224353e+01  2.900804e+00  3.668228e+00  8.872812e+00  3.041960e+00
#
#                Chol            TG           HDL           LDL          VLDL  \
# count  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03  1.000000e+03
# mean   4.263256e-17 -2.842171e-17 -3.552714e-17 -1.101341e-16 -3.907985e-17
# ...
